# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
import pandas_datareader as pdr
from datetime import datetime

# %% [markdown]
# ## For Time Series Data

# %%
import yfinance as yf

ticker = 'AAPL'
start_date = '2020-01-01'
end_date = '2023-08-01'

df = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.347946  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.634850  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.213608  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.869301  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  74.041489  132079200

# %%
import yfinance as yf
import datetime

# Set the desired date for which you want to fetch intraday data
custom_date = '2023-08-03'

# Set the start and end datetime for the single day
start = datetime.datetime.strptime(custom_date, '%Y-%m-%d')
end = start + datetime.timedelta(days=1)

# Fetch intraday data for the single day with a 5-minute interval using yfinance
ticker = 'AAPL'
data = yf.download(ticker, start=start, end=end, interval='5m')

# Print the data
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-08-03 09:30:00-04:00  191.570007  192.169998  190.690002  191.300003
# 2023-08-03 09:35:00-04:00  191.309998  191.904999  191.113998  191.789993
# 2023-08-03 09:40:00-04:00  191.790100  191.919998  191.589996  191.835007
# 2023-08-03 09:45:00-04:00  191.830002  192.279999  191.669998  191.889999
# 2023-08-03 09:50:00-04:00  191.899994  192.130005  191.830002  191.949997
# ...                               ...         ...         ...         ...
# 2023-08-03 15:35:00-04:00  191.259995  191.339996  191.059998  191.169998
# 2023-08-03 15:40:00-04:00  191.175003  191.190002  191.029999  191.070007
# 2023-08-03 15:45:00-04:00  191.070007  191.169998  190.990005  191.050003
# 2023-08-03 15:50:00-04:00  191.039993  191.490005  191.020004  191.439896
# 2023-08-03 15:55:00-04:00  191.440002  191.729996  191.009903  191.009903
#
# ...

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.347946  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.634850  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.213608  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.869301  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  74.041489  132079200

# %%
df.tail(6)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-24  193.410004  194.910004  192.250000  192.750000  192.750000
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  194.500000
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  193.220001
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.830002
# 2023-07-31  196.059998  196.490005  195.259995  196.449997  196.449997
#
#               Volume
# Date
# 2023-07-24  45377800
# 2023-07-25  37283200
# 2023-07-26  47471900
# 2023-07-27  47460200
# 2023-07-28  48291400
# 2023-07-31  38824100

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.347946  135480400
# 1 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.634850  146322800
# 2 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.213608  118387200
# 3 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.869301  108872000
# 4 2020-01-08  74.290001  76.110001  74.290001  75.797501  74.041489  132079200

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('whitegrid')  

plt.figure(figsize=(12, 6))  

plt.plot(df['Close'], color='green', linewidth=3, label='Closing Price')  # Using purple color for the plot

plt.title('Closing Price from 2000 to 2022')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.legend()

plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 895    172.9063
# 896    173.3922
# 897    173.8141
# 898    174.2341
# 899    174.6826
# Name: Close, Length: 900, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


dates = df.index.to_numpy()
close_values = df['Close'].to_numpy()

ma100_df = ma100.to_frame()

plt.figure(figsize=(12, 6))

plt.plot(dates, close_values, color='blue', linewidth=2, label='Closing Price')

plt.plot(ma100_df.index.to_numpy(), ma100_df.iloc[:, 0].to_numpy(), color='red', linewidth=2, label='Moving Average (100 days)')

plt.title('Stock Closing Prices with Moving Average (100 days)', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)

plt.grid(True, linestyle='--', linewidth=0.5)

plt.gcf().autofmt_xdate()

plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 895    157.94185
# 896    158.18720
# 897    158.45285
# 898    158.72990
# 899    159.01725
# Name: Close, Length: 900, dtype: float64

# %%
import matplotlib.pyplot as plt


dates = df.index.to_numpy()
close_values = df['Close'].to_numpy()

ma100_df = ma100.to_frame()
ma200_df = ma200.to_frame()

plt.figure(figsize=(12, 6))

plt.plot(dates, close_values, color='blue', linewidth=2, label='Closing Price')

plt.plot(ma100_df.index.to_numpy(), ma100_df.iloc[:, 0].to_numpy(), color='red', linewidth=2, label='Moving Average (100 days)')

plt.plot(ma200_df.index.to_numpy(), ma200_df.iloc[:, 0].to_numpy(), color='green', linewidth=2, label='Moving Average (200 days)')

plt.title('Stock Closing Prices with Moving Averages', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)

plt.grid(True, linestyle='--', linewidth=0.5)

plt.gcf().autofmt_xdate()

plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison between two stocks

# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt

# Replace 'api_key' with your actual Alpha Vantage API key
api_key = 'U14IRJSENTIDJU5E'

def plot_stock_comparison(stock1, stock2, start_date, end_date):
    # Retrieve the historical stock data for stock1
    df_stock1 = pdr.av.time_series.AVTimeSeriesReader(stock1, api_key=api_key, start=start_date, end=end_date).read()

    # Retrieve the historical stock data for stock2
    df_stock2 = pdr.av.time_series.AVTimeSeriesReader(stock2, api_key=api_key, start=start_date, end=end_date).read()

    # Plot the closing prices of both stocks on the same graph
    plt.figure(figsize=(12, 6))

    plt.plot(df_stock1.index.to_numpy(), df_stock1['close'].values, label=stock1, color='blue', linewidth=2)
    plt.plot(df_stock2.index.to_numpy(), df_stock2['close'].values, label=stock2, color='green', linewidth=2)

    plt.title(f'Comparison of {stock1} and {stock2} Closing Prices', fontsize=16)
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('Closing Price', fontsize=14)
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.gcf().autofmt_xdate()
    plt.legend(loc='upper left', fontsize=12)

    plt.tight_layout()
    plt.show()

# Take input from the user
stock_symbol1 = input("Enter the stock symbol for company 1: ")
stock_symbol2 = input("Enter the stock symbol for company 2: ")
start_date = input("Enter the start date (YYYY-MM-DD): ")
end_date = input("Enter the end date (YYYY-MM-DD): ")

# Call the function to plot the comparison
plot_stock_comparison(stock_symbol1, stock_symbol2, start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-25e59f07b6c6> in <module>
#      30
#      31 # Take input from the user
# ---> 32 stock_symbol1 = input("Enter the stock symbol for company 1: ")
#      33 stock_symbol2 = input("Enter the stock symbol for company 2: ")
#      34 start_date = input("Enter the start date (YYYY-MM-DD): ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

def plot_stock_comparison(stock1, stock2, start_date, end_date):
    # Retrieve the historical stock data for stock1
    df_stock1 = yf.download(stock1, start=start_date, end=end_date)

    # Retrieve the historical stock data for stock2
    df_stock2 = yf.download(stock2, start=start_date, end=end_date)

    # Plot the closing prices of both stocks on the same graph
    plt.figure(figsize=(12, 6))

    plt.plot(df_stock1.index.to_numpy(), df_stock1['Close'].values, label=stock1, color='blue', linewidth=2)
    plt.plot(df_stock2.index.to_numpy(), df_stock2['Close'].values, label=stock2, color='green', linewidth=2)

    plt.title(f'Comparison of {stock1} and {stock2} Closing Prices', fontsize=16)
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('Closing Price', fontsize=14)
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.gcf().autofmt_xdate()
    plt.legend(loc='upper left', fontsize=12)

    plt.tight_layout()
    plt.show()

# Take input from the user
stock_symbol1 = input("Enter the stock symbol for company 1: ")
stock_symbol2 = input("Enter the stock symbol for company 2: ")
start_date = input("Enter the start date (YYYY-MM-DD): ")
end_date = input("Enter the end date (YYYY-MM-DD): ")

# Call the function to plot the comparison
plot_stock_comparison(stock_symbol1, stock_symbol2, start_date, end_date)
# Out:
# Enter the stock symbol for company 1: ADANIPOWER.NS
# Enter the stock symbol for company 2: RPOWER.NS
# Enter the start date (YYYY-MM-DD): 2020-10-05
# Enter the end date (YYYY-MM-DD): 2022-10-05
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
